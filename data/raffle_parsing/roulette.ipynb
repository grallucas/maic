# %%
import pandas as pd

# %%
# Load the file data\2023 MAIC End-of-Semester Raffle(1-43).xlsx into a Pandas DataFrame (code it)
df = pd.read_excel('raffle_dfs/2023 MAIC End-of-Semester Raffle(1-43).xlsx')

# Grab only the last two columns of the DataFrame
df = df.iloc[:, -2:]
df
# Out:
#    First and Last Name (FREE Raffle Ticket)  \
# 0                          Travis Jankowski
# 1                             Noah nieberle
# 2                             Jacob Minikel
# 3                                Alex Ewart
# 4                              Samir Mahmud
# 5                     Hugo garrido-lestache
# 6                            Vincenzo Bean
# 7                    Krueger (Mac) Williams
# 8                                  Andy Dao
# 9                            caleb andreano
# 10                         Benjamin gadiano
# 11                              Jacob Tyree
# 12                       Wendpanga Tapsoba
# 13                            Trent Adamson
# 14                              JT Wehmeier
# 15                          Gavin Childress
# 16                             Aaron Herbst
# 17                        Christian Zastrow
# 18                           Cody Steinmetz
# 19                          Christian Basso
# 20                         Keagan Weinstock
# 21                              Vlad Miziuk
# 22                          Charles Nortrup
# 23                              Aydin Ruppe
# 24                              Sonia Grade
# 25                        James Prendiville
# 26                               Liam Otten
# 27                         Helina Mulugeta
# 28                              Jack Dorner
# 29                             Evan Nowlin
# 30                        Owen Bailey-Waltz
# 31                               Ryan Giese
# 32                            Annika Peters
# 33                         Mikhail Filippov
# 34                             Colton Waltz
# 35                             Aiden Miller
# 36                         Nikolas Palacios
# 37                            Nathan Miller
# 38                                Alex Toma
# 39                          Mia Hochstetler
# 40                           Levi Wolfgramm
# 41                            Dominic Zagra
# 42                               Sam Keyser
#
#     If you would like to spend AI-Club points for additional slots in the raffle, please denote the amount you would like to spend here. (Check out the website for your points; http://msoe-maic.com)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 1.0
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 0.0
# 8                                                 0.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                0.0
# 14                                                3.0
# 15                                                0.0
# 16                                                NaN
# 17                                                7.0
# 18                                                6.0
# 19                                                4.0
# 20                                                NaN
# 21                                                NaN
# 22                                                2.0
# 23                                                6.0
# 24                                                NaN
# 25                                                0.0
# 26                                                3.0
# 27                                                NaN
# 28                                                2.0
# 29                                                0.0
# 30                                                NaN
# 31                                                0.0
# 32                                                NaN
# 33                                                2.0
# 34                                                NaN
# 35                                                5.0
# 36                                                0.0
# 37                                                0.0
# 38                                                NaN
# 39                                                5.0
# 40                                                0.0
# 41                                                4.0
# 42                                                0.0

# %% [markdown]
# ### Create a list that is Easy to Input Into Online Roulette Wheel
# https://wheelofnames.com/

# %%
# Given the dataframe, create a new dataframe where a name is repeated x number of rows, where x is the number denoted in the second column. If the number is NaN or 0, then inlcude the person only once

# Create a new dataframe
entries = []

# Iterate through each row in the dataframe

for index, row in df.iterrows():
    # Get the name and number of times to repeat
    name = row[-2]
    num = row[-1]
    
    # If the number is NaN or 0, then include the person only once
    if pd.isnull(num) or num == 0:
        entries.append(name)
    else:
        # Repeat the person x number of times
        for i in range(int(num) + 1):
            entries.append(name)

entries
# Out:
# ['Travis Jankowski',
#  'Noah nieberle',
#  'Jacob Minikel',
#  'Alex Ewart',
#  'Alex Ewart',
#  'Samir Mahmud',
#  'Hugo garrido-lestache',
#  'Vincenzo Bean ',
#  'Krueger (Mac) Williams',
#  'Andy Dao',
#  'caleb andreano',
#  'Benjamin gadiano',
#  'Jacob Tyree',
#  'Wendpanga Tapsoba ',
#  'Trent Adamson',
#  'JT Wehmeier',
#  'JT Wehmeier',
#  'JT Wehmeier',
#  'JT Wehmeier',
#  'Gavin Childress',
#  'Aaron Herbst',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Christian Zastrow',
#  'Cody Steinmetz',
#  'Cody Steinmetz',
#  'Cody Steinmetz',
#  'Cody Steinmetz',
#  'Cody Steinmetz',
#  'Cody Steinmetz',
#  'Cody Steinmetz',
#  'Christian Basso',
#  'Christian Basso',
#  'Christian Basso',
#  'Christian Basso',
#  'Christian Basso',
#  'Keagan Weinstock',
#  'Vlad Miziuk',
#  'Charles Nortrup',
#  'Charles Nortrup',
#  'Charles Nortrup',
#  'Aydin Ruppe',
#  'Aydin Ruppe',
#  'Aydin Ruppe',
#  'Aydin Ruppe',
#  'Aydin Ruppe',
#  'Aydin Ruppe',
#  'Aydin Ruppe',
#  'Sonia Grade',
#  'James Prendiville',
#  'Liam Otten',
#  'Liam Otten',
#  'Liam Otten',
#  'Liam Otten',
#  'Helina Mulugeta ',
#  'Jack Dorner',
#  'Jack Dorner',
#  'Jack Dorner',
#  'Evan Nowlin ',
#  'Owen Bailey-Waltz',
#  'Ryan Giese',
#  'Annika Peters',
#  'Mikhail Filippov',
#  'Mikhail Filippov',
#  'Mikhail Filippov',
#  'Colton Waltz',
#  'Aiden Miller',
#  'Aiden Miller',
#  'Aiden Miller',
#  'Aiden Miller',
#  'Aiden Miller',
#  'Aiden Miller',
#  'Nikolas Palacios',
#  'Nathan Miller',
#  'Alex Toma',
#  'Mia Hochstetler',
#  'Mia Hochstetler',
#  'Mia Hochstetler',
#  'Mia Hochstetler',
#  'Mia Hochstetler',
#  'Mia Hochstetler',
#  'Levi Wolfgramm',
#  'Dominic Zagra',
#  'Dominic Zagra',
#  'Dominic Zagra',
#  'Dominic Zagra',
#  'Dominic Zagra',
#  'Sam Keyser']

# %% [markdown]
# ### Better DF Format
# Get the df into a format which is easy to remove the points from the online leaderboard

# %%
# For df, replace all Nan values with 0 (Free point)
df = df.fillna(0)

# Rename the first column to 'Name' and the second column to 'Points'
df.columns = ['Name', 'Points']
df

# For each name, get rid of white space surrounding the name and title the string
df['Name'] = df['Name'].str.strip().str.title()
df
# Out:
#                       Name  Points
# 0         Travis Jankowski     0.0
# 1            Noah Nieberle     0.0
# 2            Jacob Minikel     0.0
# 3               Alex Ewart     1.0
# 4             Samir Mahmud     0.0
# 5    Hugo Garrido-Lestache     0.0
# 6            Vincenzo Bean     0.0
# 7   Krueger (Mac) Williams     0.0
# 8                 Andy Dao     0.0
# 9           Caleb Andreano     0.0
# 10        Benjamin Gadiano     0.0
# 11             Jacob Tyree     0.0
# 12       Wendpanga Tapsoba     0.0
# 13           Trent Adamson     0.0
# 14             Jt Wehmeier     3.0
# 15         Gavin Childress     0.0
# 16            Aaron Herbst     0.0
# 17       Christian Zastrow     7.0
# 18          Cody Steinmetz     6.0
# 19         Christian Basso     4.0
# 20        Keagan Weinstock     0.0
# 21             Vlad Miziuk     0.0
# 22         Charles Nortrup     2.0
# 23             Aydin Ruppe     6.0
# 24             Sonia Grade     0.0
# 25       James Prendiville     0.0
# 26              Liam Otten     3.0
# 27         Helina Mulugeta     0.0
# 28             Jack Dorner     2.0
# 29             Evan Nowlin     0.0
# 30       Owen Bailey-Waltz     0.0
# 31              Ryan Giese     0.0
# 32           Annika Peters     0.0
# 33        Mikhail Filippov     2.0
# 34            Colton Waltz     0.0
# 35            Aiden Miller     5.0
# 36        Nikolas Palacios     0.0
# 37           Nathan Miller     0.0
# 38               Alex Toma     0.0
# 39         Mia Hochstetler     5.0
# 40          Levi Wolfgramm     0.0
# 41           Dominic Zagra     4.0
# 42              Sam Keyser     0.0

# %%
user_data = pd.read_csv('../../data/User_Data.csv')
user_data
# Out:
#                User       Description  \
# 0       Ben Paulson  test description
# 1        Lucas Gral  test description
# 2    Sydney Balboni  test description
# 3       John Cisler  test description
# 4     Evan Schubert  test description
# ..              ...               ...
# 235   Tanner Cellio  test description
# 236     Jonny Keane  test description
# 237     Miko Sordyl  test description
# 238     Ian Czerkis  test description
# 239      Ella Bruce  test description
#
#                                                 Awards  All-Time Points  \
# 0    NVIDIA DLI 2023|ROSIE Presenter|eboard2022|ebo...               54
# 1    Overlord|eboard2022|eboard2023|2022 Researcher...               37
# 2    NVIDIA DLI 2023|ROSIE Presenter|eboard2023|ROS...               28
# 3    ROSIE Presenter|eboard2023|ROSIE Competition F...               15
# 4                                                  NaN                4
# ..                                                 ...              ...
# 235                                                NaN                1
# 236                                                NaN                1
# 237                                                NaN                0
# 238                                                NaN                1
# 239                                         eboard2023               10
#
#      Current Points
# 0                49
# 1                37
# 2                27
# 3                14
# 4                 4
# ..              ...
# 235               1
# 236               1
# 237               0
# 238               1
# 239              10
#
# [240 rows x 5 columns]

# %%
# Given the amount of points associated with each Name in df, remove those points from user_data 'Current Points'
for index, row in df.iterrows():
    name = row['Name']
    points = row['Points']
    
    # Find the index of the name in user_data
    user_index = user_data[user_data['User'] == name]

    # If user index empty, skip
    if user_index.empty:
        continue

    # Get the index of the user
    user_index = user_index.index[0]
    
    # Subtract the points from the 'Current Points' column
    user_data.loc[user_index, 'Current Points'] = user_data.loc[user_index, 'Current Points'] - points

user_data[user_data['User'] == 'Christian Zastrow']
# Out:
#                   User       Description           Awards  All-Time Points  \
# 143  Christian Zastrow  test description  NVIDIA DLI 2023                7
#
#      Current Points
# 143               0

# %%
user_data.to_csv('../../data/User_Data.csv', index=False)
